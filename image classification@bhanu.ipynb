# %% [markdown]
# # Handwritten Number classification using CNN.

# %% [markdown]
# # Group members

# %% [markdown]
# Yeshwanth Reddy Peddola
# Bhanu Chander Mudeli
# Harish Reddy Kadukuntla
# Sai Kumar Garshakurthi

# %% [markdown]
# ### installing Tensorflow library

# %% [markdown]
# TensorFlow, an open-source machine learning framework developed by Google, is extensively used for diverse machine learning tasks, such as constructing and training neural networks. It offers a flexible array of tools, libraries, and community support, catering to the development of machine learning models.
#
# This framework enables the creation and deployment of machine learning models across various platforms and devices, accommodating both research and production settings. TensorFlow offers convenient high-level APIs like Keras for streamlined model construction and training, alongside lower-level APIs that grant users more control and adaptability.
#
# Getting started with TensorFlow involves installing it via Python's package manager, pip, as mentioned earlier. Once installed, you can import TensorFlow into your Python environment to commence working on building and training machine learning models.

# %% [markdown]
# # Reference--
# Ketkar, N. and Ketkar, N., 2017. Introduction to tensorflow., pp.159-194.

# %% [markdown]
# Singh, Pramod, Avinash Manure, Pramod Singh, and Avinash Manure. "Introduction to tensorflow 2.0."

# %%
pip install tensorflow
# Out:
# ...
#                                               0.0/300.8 MB ? eta -:--:--
#                                               0.1/300.8 MB 1.7 MB/s eta 0:02:53
#                                               0.3/300.8 MB 2.3 MB/s eta 0:02:14
#                                               0.4/300.8 MB 2.3 MB/s eta 0:02:10
#                                               0.7/300.8 MB 3.1 MB/s eta 0:01:38
#                                               1.6/300.8 MB 5.3 MB/s eta 0:00:57
#                                               1.6/300.8 MB 5.1 MB/s eta 0:00:59
#                                               1.9/300.8 MB 4.8 MB/s eta 0:01:03
#                                               2.9/300.8 MB 6.2 MB/s eta 0:00:49
#                                               3.6/300.8 MB 6.9 MB/s eta 0:00:44
#                                               4.7/300.8 MB 8.6 MB/s eta 0:00:35
#                                               5.6/300.8 MB 9.4 MB/s eta 0:00:32
# ...

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 1.3 MB/s eta 0:00:06
#                                               0.1/7.6 MB 1.6 MB/s eta 0:00:05
#      -                                        0.3/7.6 MB 2.1 MB/s eta 0:00:04
#      --                                       0.5/7.6 MB 2.3 MB/s eta 0:00:04
#      ----                                     0.8/7.6 MB 3.2 MB/s eta 0:00:03
#      -------                                  1.4/7.6 MB 4.8 MB/s eta 0:00:02
#      ----------                               2.0/7.6 MB 6.0 MB/s eta 0:00:01
#      --------------                           2.8/7.6 MB 7.2 MB/s eta 0:00:01
#      -----------------                        3.4/7.6 MB 8.1 MB/s eta 0:00:01
#      --------------------                     3.9/7.6 MB 8.1 MB/s eta 0:00:01
#      ------------------------                 4.7/7.6 MB 9.1 MB/s eta 0:00:01
# ...

# %% [markdown]
# # installing keras
# Keras, initially created by François Chollet, stands as an open-source neural network library written in Python. Its primary aim is to provide a user-friendly, modular, and easily navigable platform for developing and prototyping neural network models. Over time, Keras has merged into TensorFlow, functioning as its higher-level API.
#
# This library streamlines the process of constructing, designing, and training neural networks, abstracting the complexities commonly found in lower-level operations. Keras simplifies the definition of neural network models by offering accessible building blocks like layers, activation functions, optimizers, loss functions, and other essential components.

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Tenserflow, Matplot and Numpy

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\envs\iris\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Version Check for Tensorflow, Matplot and Numpy

# %%
print(tf.__version__)
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 2.15.0
# 3.8.1
# 1.26.2

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train[10].shape
# Out:
# (28, 28)

# %% [markdown]
# # Using Matplot to show the image

# %%
plt.matshow(X_train[10])

# %%
y_train[10]
# Out:
# 3

# %% [markdown]
# # Normalising the training data

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # Activation Function:
# Relu-They determine the output of a model, its accuracy, and computational efficiency. In some cases, activation functions have a major effect on the model's ability to converge and the convergence speed.
# Sigmoid- The sigmoid function's ability to transform any real number to one between 0 and 1 is advantageous in data science and many other fields such as: In deep learning as a non-linear activation function within neurons in artificial neural networks to allows the network to learn non-linear relationships between the data.

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\envs\iris\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\envs\iris\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\envs\iris\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\envs\iris\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# ...

# %%
model.evaluate(X_test,y_test)

# %%
X_train = X_train.reshape(-1,28,28,1)
X_train.shape

# %%
X_test = X_test.reshape(-1,28,28,1)
X_test.shape

# %% [markdown]
# # CNN Classification
# Image classification using Convolutional Neural Networks (CNN) has revolutionized computer vision tasks by enabling automated and accurate recognition of objects within images. CNN-based image classification algorithms have gained immense popularity due to their ability to learn and extract intricate features from raw image data automatically. This article will explore the principles, techniques, and applications of image classification using CNNs. We will delve into the architecture, training process, and CNN image classification evaluation metrics. By understanding the workings of CNNs for image classification, we can unlock many possibilities for object recognition, scene understanding, and visual data analysis

# %%
model = keras.Sequential([
    
    layers.Conv2D(30, (3,3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2,2)),
 
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

# %% [markdown]
# # Epochs For evaluating Accuracy
# Epochs objects are a data structure for representing and analyzing equal-duration chunks of the EEG/MEG signal. Epochs are most often used to represent data that is time-locked to repeated experimental events (such as stimulus onsets or subject button presses), but can also be used for storing sequential or overlapping frames of a continuous signal (e.g., for analysis of resting-state activity; see Making equally-spaced Events arrays). Inside an Epochs object, the data are stored in an array of shape.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.0184 - accuracy: 0.9945
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0144 - accuracy: 0.9955
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0126 - accuracy: 0.9960
# Epoch 4/20
# 1810/1875 [===========================>..] - ETA: 0s - loss: 0.0112 - accuracy: 0.9967

# %%
y_train[:5]

# %%
model.evaluate(X_test,y_test)

# %% [markdown]
# # Reflection
# The described system employs Convolutional Neural Networks (CNNs) to differentiate between four distinct types of visual blur: motion blur, defocus, and Gaussian blurs. It involves transforming input images into a higher-dimensional feature space and utilizes supervised learning to accurately classify them. To prevent overfitting and expedite convergence, the model replaces removal approaches with group normalization layers. Its systematic approach is well-suited for beginners or straightforward tasks, ensuring a logical and structured network architecture.
#
# While employing 'softmax' in the output layer, the activation function in intermediate layers is used. Understanding the challenges involved and evaluating the model's applicability requires this background information. Dense networks like this one can tend to overfit, particularly with small or similar datasets, thus benefiting from techniques like data augmentation or regularization to mitigate this risk.
#
# Overall, the model serves as a robust framework for applying neural networks to image classification, effectively showcasing key concepts in deep learning. Future improvements could involve exploring more intricate architectures suitable for image data, better managing overfitting, and incorporating diverse evaluation criteria.

# %% [markdown]
# # Advantges
# CNNs have versatile applications extending beyond image recognition, encompassing tasks like medical imaging analysis, document categorization, video comprehension, and a variety of other classification endeavors.
#
#
# CNNs have versatile applications extending beyond image recognition, encompassing tasks like medical imaging analysis, document categorization, video comprehension, and a variety of other classification endeavors.

# %% [markdown]
# # Disadvantages

# %% [markdown]
# CNNs are commonly seen as opaque models, implying that comprehending their decision-making process, particularly in intricate architectures with multiple layers, can be difficult. Grasping the rationale behind a CNN's specific classification can pose a challenge.

# %% [markdown]
# CNNs can be vulnerable to adversarial attacks, wherein tiny alterations to an input image, even undetectable to humans, might cause misclassification. These vulnerabilities can present security concerns in specific applications.

# %% [markdown]
# # Reference
# Elngar, A.A., Arafa, M., Fathy, A., Moustafa, B., Mahmoud, O., Shaban, M. and Fawzy, N., 2021. Image classification based on CNN: 6(1), pp.18-50.
# Han, D., Liu, Q. and Fan, W., 2018. , pp.43-56.
# Yu, S., Jia, S. and Xu, C., 2017. Convolutional neural networks  image classification. Neurocomputing, 219, pp.88-98.
